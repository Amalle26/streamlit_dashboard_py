# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv("RECLAMEAQUI_HAPVIDA.csv")

# %%
df.head(5)
# Out:
#           ID                                             TEMA           LOCAL  \
# 0  149490335                            TEMPO DE ATENDIMENTO      Recife - PE
# 1  149499817                       Hapvida não tem nutrólogo    Salvador - BA
# 2  149498293             Descaso de tratamento de Hemodiálise     Olinda - PE
# 3  149495455  DESORGANIZAÇÃO E FALTA DE RESOLUÇÃO DE PROBLEMA    Goiânia - GO
# 4  149495285                       Liberação de Procedimento   Fortaleza - CE
#
#         TEMPO                                          CATEGORIA  \
# 0  2022-01-09  Demora na execução<->Plano<->Planos de Saúde<-...
# 1  2022-01-09  Planos de saúde<->Qualidade do serviço prestad...
# 2  2022-01-09  Demora para autorização de consultas, exames e...
# 3  2022-01-09  Demora na execução<->Planos de saúde<->Planos ...
# 4  2022-01-09  Planos de saúde<->Planos de Saúde<->Hapvida Sa...
#
#            STATUS                                          DESCRICAO  \
# 0  Não respondida  Acabei de sair de uma urgência por causa de at...
# 1  Não respondida  O Hapvida diz que fornece o serviço de nutrólo...
# 2      Respondida  Meu irmão Wagner Santiago, estava internado de...
# 3  Não respondida  Agendei pelo chat um procedimento onde fui bem...
# 4      Respondida  Paguei fatura do plano em atraso e tal atraso ...
#
#                                                  URL   ANO  MES  DIA  \
# 0  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 1  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 2  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 3  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 4  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
#
#    DIA_DO_ANO  SEMANA_DO_ANO  DIA_DA_SEMANA  TRIMETRES  CASOS
# 0           9              1              6          1     66
# 1           9              1              6          1     66
# 2           9              1              6          1     66
# 3           9              1              6          1     66
# 4           9              1              6          1     66

# %%
df['TEMPO'] = pd.to_datetime(df['TEMPO'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1016 entries, 0 to 1015
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             1016 non-null   int64
#  1   TEMA           1016 non-null   object
#  2   LOCAL          1016 non-null   object
#  3   TEMPO          1016 non-null   datetime64[ns]
#  4   CATEGORIA      1016 non-null   object
#  5   STATUS         1016 non-null   object
#  6   DESCRICAO      1016 non-null   object
#  7   URL            1016 non-null   object
#  8   ANO            1016 non-null   int64
#  9   MES            1016 non-null   int64
#  10  DIA            1016 non-null   int64
#  11  DIA_DO_ANO     1016 non-null   int64
#  12  SEMANA_DO_ANO  1016 non-null   int64
#  13  DIA_DA_SEMANA  1016 non-null   int64
#  14  TRIMETRES      1016 non-null   int64
#  15  CASOS          1016 non-null   int64
# dtypes: datetime64[ns](1), int64(9), object(6)
# memory usage: 127.1+ KB

# %%
df['TEMPO']
# Out:
# 0      2022-01-09
# 1      2022-01-09
# 2      2022-01-09
# 3      2022-01-09
# 4      2022-01-09
#           ...
# 1011   2022-12-09
# 1012   2022-12-09
# 1013   2022-12-09
# 1014   2022-12-09
# 1015   2022-12-09
# Name: TEMPO, Length: 1016, dtype: datetime64[ns]

# %%
df.groupby('TEMPO').nunique()['ID'].plot()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: xlabel='TEMPO'>

# %%
df['STATUS'].value_counts()
# Out:
# STATUS
# Não respondida    639
# Respondida        271
# Resolvido          67
# Em réplica         36
# Não resolvido       3
# Name: count, dtype: int64

# %%
freq_hapvida = df['STATUS'].value_counts().reset_index()
freq_hapvida.columns = ['STATUS','Frequencia']

# %%
freq_hapvida
# Out:
#            STATUS  Frequencia
# 0  Não respondida         639
# 1      Respondida         271
# 2       Resolvido          67
# 3      Em réplica          36
# 4   Não resolvido           3

# %%
px.bar(freq_hapvida, x='STATUS', y='Frequencia', title='Frequência dos Status', labels={'Frequencia': 'Contagem'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\cissa\Desktop\streamlit_dashboard_py\streamlit_dashboard_py\venv\Lib\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File c:\Users\cissa\Desktop\streamlit_dashboard_py\streamlit_dashboard_py\venv\Lib\site-packages\plotly\basedatatypes.py:833, in BaseFigure._ipython_display_(self)
#     830 import plotly.io as pio
#     832 if pio.renderers.render_on_display and pio.renderers.default:
# --> 833     pio.show(self)
#     834 else:
#     835     print(repr(self))
#
# File c:\Users\cissa\Desktop\streamlit_dashboard_py\streamlit_dashboard_py\venv\Lib\site-packages\plotly\io\_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
#     421         "Mime type rendering requires ipython but it is not installed"
#     422     )
#     424 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 425     raise ValueError(
#     426         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     427     )
#     429 display_jupyter_version_warnings()
#     431 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'STATUS=%{x}<br>Contagem=%{y}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#636efa', 'pattern': {'shape': ''}},
#               'name': '',
#               'orientation': 'v',
#               'showlegend': False,
#               'textposition': 'auto',
#               'type': 'bar',
#               'x': array(['Não respondida', 'Respondida', 'Resolvido', 'Em réplica',
#                           'Não resolvido'], dtype=object),
#               'xaxis': 'x',
#               'y': {'bdata': 'fwIPAUMAJAADAA==', 'dtype': 'i2'},
#               'yaxis': 'y'}],
#     'layout': {'barmode': 'relative',
#                'legend': {'tracegroupgap': 0},
#                'template': '...',
#                'title': {'text': 'Frequência dos Status'},
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'STATUS'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'Contagem'}}}
# })

# %%
df['LOCAL'].iloc[0]
# Out:
# 'Recife - PE'

# %%
df['LOCAL'].iloc[0].split('-')[1].strip()
# Out:
# 'PE'

# %%
estado_lista = []
for i in range(len(df)):
    estado_lista.append(df['LOCAL'].iloc[i].split('-',2)[1].strip())

# %%
estado_lista
# Out:
# ['PE',
#  'BA',
#  'PE',
#  'GO',
#  'CE',
#  'BA',
#  'SP',
#  'BA',
#  'BA',
#  'BA',
#  'PE',
#  'MA',
#  'GO',
#  'PA',
#  'PE',
#  'BA',
#  'SP',
#  'PE',
#  'AL',
#  'CE',
#  'RN',
#  'CE',
#  'CE',
#  'BA',
#  'PE',
#  'BA',
#  'GO',
#  'CE',
#  'PE',
#  'GO',
#  'BA',
#  'RN',
#  'CE',
#  'SP',
#  'RN',
#  'CE',
#  'PB',
#  'SP',
#  'AL',
#  'BA',
#  'BA',
#  'PB',
#  'RN',
#  'SP',
#  '',
#  'GO',
#  'SP',
#  'MS',
#  'MS',
#  'MS',
#  'SP',
#  'SP',
#  'AL',
#  'PE',
#  'BA',
#  'ES',
#  'BA',
#  'MS',
#  'MA',
#  'BA',
#  'SP',
#  'SP',
#  'SP',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'BA',
#  'GO',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'GO',
#  'PE',
#  'SP',
#  'CE',
#  'PB',
#  'PB',
#  'RN',
#  'PE',
#  'AM',
#  'CE',
#  'CE',
#  'MT',
#  'CE',
#  'PE',
#  'AL',
#  'PE',
#  'CE',
#  'RN',
#  'BA',
#  'SP',
#  'PE',
#  'CE',
#  'PE',
#  'CE',
#  'SP',
#  'PA',
#  'PE',
#  'RN',
#  'BA',
#  'MS',
#  'RN',
#  'PA',
#  'BA',
#  'AL',
#  'SP',
#  'SP',
#  'CE',
#  'PE',
#  'GO',
#  'SP',
#  'GO',
#  'SP',
#  'CE',
#  'CE',
#  'AL',
#  'BA',
#  'GO',
#  'CE',
#  'CE',
#  'SE',
#  'PE',
#  'PE',
#  'CE',
#  'SP',
#  'PE',
#  'RN',
#  'BA',
#  'SP',
#  'PB',
#  'BA',
#  'PE',
#  'CE',
#  'CE',
#  'GO',
#  'BA',
#  'SP',
#  'GO',
#  'PE',
#  'SE',
#  'AM',
#  'SP',
#  'GO',
#  'CE',
#  'CE',
#  'AM',
#  'MG',
#  'SE',
#  'GO',
#  'BA',
#  'BA',
#  'PE',
#  'SP',
#  'PE',
#  'CE',
#  'PE',
#  'PE',
#  'BA',
#  'SP',
#  'PE',
#  'CE',
#  'PE',
#  'CE',
#  'RN',
#  'BA',
#  'PE',
#  'SP',
#  'PE',
#  'CE',
#  'AL',
#  'PE',
#  'BA',
#  'CE',
#  'BA',
#  'BA',
#  'GO',
#  'GO',
#  'BA',
#  'GO',
#  'SP',
#  'GO',
#  'BA',
#  'BA',
#  'CE',
#  'SP',
#  'SP',
#  'PE',
#  'CE',
#  'CE',
#  'BA',
#  'PE',
#  'PA',
#  'PE',
#  'CE',
#  'SP',
#  'BA',
#  'CE',
#  'PA',
#  'RN',
#  'PE',
#  'RS',
#  'CE',
#  'GO',
#  'PE',
#  'CE',
#  'PA',
#  'PA',
#  'PE',
#  'BA',
#  'CE',
#  'PE',
#  'RR',
#  'BA',
#  'BA',
#  'SP',
#  'SP',
#  'SP',
#  'PE',
#  'CE',
#  'PE',
#  'GO',
#  'CE',
#  'CE',
#  'SP',
#  'CE',
#  'BA',
#  'BA',
#  'PE',
#  'CE',
#  'AM',
#  'PE',
#  'MS',
#  'RJ',
#  'GO',
#  'RN',
#  'PA',
#  'CE',
#  'RN',
#  'CE',
#  'GO',
#  'GO',
#  'PE',
#  'SP',
#  'CE',
#  'SE',
#  'PE',
#  'PE',
#  'PE',
#  'SP',
#  'AM',
#  'SP',
#  'CE',
#  'PB',
#  'MG',
#  'GO',
#  'SP',
#  'MG',
#  'PE',
#  'CE',
#  'SP',
#  'BA',
#  'PA',
#  'GO',
#  'BA',
#  'MT',
#  'PE',
#  'MA',
#  'BA',
#  'SP',
#  'BA',
#  'SP',
#  'RN',
#  'SP',
#  'GO',
#  'MS',
#  'SP',
#  'CE',
#  'CE',
#  'CE',
#  'AM',
#  'RN',
#  'PE',
#  'MG',
#  'BA',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'SP',
#  'CE',
#  'CE',
#  'PE',
#  'RN',
#  'BA',
#  'PE',
#  'PA',
#  'MS',
#  'PB',
#  'SP',
#  'GO',
#  'SE',
#  'GO',
#  'CE',
#  'PA',
#  'PE',
#  'SP',
#  'SP',
#  'BA',
#  'GO',
#  'BA',
#  'CE',
#  'SP',
#  'PE',
#  'PE',
#  'SP',
#  'CE',
#  'CE',
#  'BA',
#  'PB',
#  'CE',
#  'CE',
#  'CE',
#  'GO',
#  'BA',
#  'GO',
#  'BA',
#  'PE',
#  'BA',
#  'RN',
#  'CE',
#  'CE',
#  'SP',
#  'CE',
#  'MA',
#  'AM',
#  'PB',
#  'MS',
#  'SP',
#  'CE',
#  'AM',
#  'AL',
#  '',
#  'CE',
#  'SP',
#  'SP',
#  'SP',
#  'PE',
#  'BA',
#  'BA',
#  'CE',
#  'GO',
#  'BA',
#  'BA',
#  'BA',
#  'SP',
#  'SP',
#  'PE',
#  'CE',
#  'RJ',
#  'PE',
#  'PE',
#  'BA',
#  'PA',
#  'RN',
#  'CE',
#  'SP',
#  'SP',
#  'CE',
#  'SP',
#  'PE',
#  'CE',
#  'GO',
#  'MA',
#  'RN',
#  'CE',
#  'PE',
#  'SP',
#  'GO',
#  'MS',
#  'PB',
#  'MS',
#  'SP',
#  'PE',
#  'CE',
#  'PE',
#  'PE',
#  'CE',
#  'GO',
#  'AM',
#  'CE',
#  'SP',
#  'BA',
#  'CE',
#  'MS',
#  'BA',
#  'RS',
#  'PE',
#  'PE',
#  'CE',
#  'SP',
#  'CE',
#  'GO',
#  'PE',
#  'CE',
#  'RN',
#  'SP',
#  'SP',
#  'PE',
#  'SP',
#  'PA',
#  'SC',
#  'PE',
#  'BA',
#  'CE',
#  'RN',
#  'MS',
#  'PE',
#  'CE',
#  'BA',
#  'MT',
#  'SP',
#  'RN',
#  'CE',
#  'PE',
#  'PB',
#  'CE',
#  'RN',
#  'CE',
#  'PE',
#  'RN',
#  'PI',
#  'CE',
#  'MS',
#  'PA',
#  'BA',
#  'SP',
#  'CE',
#  'SP',
#  'SP',
#  'SP',
#  'SP',
#  'PE',
#  'PE',
#  'SP',
#  'PE',
#  'CE',
#  'BA',
#  'BA',
#  'CE',
#  'PE',
#  'GO',
#  'BA',
#  'AM',
#  'BA',
#  'PE',
#  'PE',
#  'PE',
#  'SE',
#  'BA',
#  'RN',
#  'CE',
#  'PB',
#  'PE',
#  'PE',
#  'SP',
#  'PE',
#  'ES',
#  'CE',
#  'CE',
#  'CE',
#  'SE',
#  'CE',
#  'CE',
#  'BA',
#  'PA',
#  'CE',
#  'PI',
#  'CE',
#  'PE',
#  'PE',
#  'BA',
#  'PE',
#  'PE',
#  'SE',
#  'GO',
#  'PB',
#  'CE',
#  'ES',
#  'SP',
#  'AL',
#  'AL',
#  'AM',
#  'SP',
#  'CE',
#  'BA',
#  'CE',
#  'CE',
#  'BA',
#  'BA',
#  'BA',
#  'PE',
#  'BA',
#  'PE',
#  'MA',
#  'SP',
#  'BA',
#  'SP',
#  'PA',
#  'CE',
#  'RN',
#  'CE',
#  'PE',
#  'CE',
#  'PE',
#  'PE',
#  'RN',
#  'SP',
#  'PE',
#  'BA',
#  'PE',
#  'SP',
#  'BA',
#  'CE',
#  'AM',
#  'BA',
#  'BA',
#  'SP',
#  'BA',
#  'GO',
#  'RN',
#  'BA',
#  'GO',
#  'CE',
#  'PE',
#  'SP',
#  'RN',
#  'GO',
#  'PE',
#  'BA',
#  'SP',
#  'SP',
#  'TO',
#  'SC',
#  'PE',
#  'AL',
#  'PE',
#  'CE',
#  'BA',
#  'MG',
#  'BA',
#  'PE',
#  'BA',
#  'BA',
#  'AM',
#  'CE',
#  'GO',
#  'PB',
#  'BA',
#  'CE',
#  'PE',
#  'SP',
#  'GO',
#  'SP',
#  'BA',
#  'PE',
#  'GO',
#  'AL',
#  'SP',
#  'BA',
#  'CE',
#  'AM',
#  'PE',
#  'SP',
#  'PE',
#  'SP',
#  'BA',
#  'SP',
#  'PE',
#  'GO',
#  'CE',
#  'SC',
#  'GO',
#  'PE',
#  'BA',
#  'SC',
#  'BA',
#  'BA',
#  'DF',
#  'CE',
#  'GO',
#  'SP',
#  'PE',
#  'RN',
#  'MT',
#  'BA',
#  'PB',
#  'CE',
#  'MA',
#  'CE',
#  'PE',
#  'GO',
#  'PE',
#  'CE',
#  'RN',
#  'CE',
#  'PE',
#  'CE',
#  'BA',
#  'PE',
#  'CE',
#  'PE',
#  'SP',
#  'RN',
#  'GO',
#  'GO',
#  'GO',
#  'CE',
#  'BA',
#  'CE',
#  'SC',
#  'BA',
#  'BA',
#  'RN',
#  'GO',
#  'MA',
#  'PE',
#  'AM',
#  'BA',
#  'SP',
#  'GO',
#  'SP',
#  'PA',
#  'CE',
#  'PE',
#  'PE',
#  'BA',
#  'PE',
#  'CE',
#  'SP',
#  'PE',
#  'RJ',
#  'CE',
#  'BA',
#  'BA',
#  'MG',
#  'PB',
#  'CE',
#  'PE',
#  'PE',
#  'SP',
#  'PE',
#  'BA',
#  'BA',
#  'CE',
#  'PA',
#  'GO',
#  'SP',
#  'MG',
#  'PE',
#  'BA',
#  'PB',
#  'SP',
#  'AM',
#  'AL',
#  'BA',
#  'PE',
#  'PE',
#  'PE',
#  'BA',
#  'BA',
#  'PE',
#  'MA',
#  'BA',
#  'CE',
#  'MA',
#  'CE',
#  'CE',
#  'SC',
#  'SP',
#  'GO',
#  'SP',
#  'MS',
#  'RN',
#  'RN',
#  'BA',
#  'CE',
#  'CE',
#  'SE',
#  'GO',
#  'GO',
#  'PE',
#  'GO',
#  'CE',
#  'BA',
#  'SP',
#  'BA',
#  'CE',
#  'RN',
#  'GO',
#  'CE',
#  'GO',
#  'CE',
#  'SP',
#  'BA',
#  'AL',
#  'RN',
#  'PB',
#  'RN',
#  'DF',
#  'PE',
#  'CE',
#  'RN',
#  'CE',
#  'GO',
#  'CE',
#  'CE',
#  'GO',
#  'PB',
#  'PA',
#  'CE',
#  'PE',
#  'SP',
#  'PE',
#  'PE',
#  'PE',
#  'AM',
#  'PE',
#  'MG',
#  'GO',
#  'GO',
#  'GO',
#  'MS',
#  'RN',
#  'DF',
#  'SP',
#  'CE',
#  'BA',
#  'AL',
#  'SP',
#  'PB',
#  'AM',
#  'CE',
#  'CE',
#  'PA',
#  'GO',
#  'CE',
#  'SP',
#  'CE',
#  'SE',
#  'AM',
#  'PE',
#  'SP',
#  'CE',
#  'GO',
#  'CE',
#  'SP',
#  'BA',
#  'PE',
#  'GO',
#  'CE',
#  'SP',
#  'SP',
#  'BA',
#  'BA',
#  'CE',
#  'PE',
#  'PE',
#  'PE',
#  'PE',
#  'PE',
#  'CE',
#  'CE',
#  'CE',
#  'CE',
#  'MA',
#  'PE',
#  'PE',
#  'SP',
#  'CE',
#  'CE',
#  'SP',
#  'PA',
#  'CE',
#  'SP',
#  'PE',
#  'SE',
#  'CE',
#  'GO',
#  'CE',
#  'RN',
#  'CE',
#  'PE',
#  'CE',
#  'CE',
#  'PI',
#  'SP',
#  'RN',
#  'AL',
#  'RN',
#  'BA',
#  'GO',
#  'CE',
#  'PI',
#  'CE',
#  'RN',
#  'AM',
#  'PB',
#  'PE',
#  'RN',
#  'MS',
#  'PE',
#  'AL',
#  'MS',
#  'MS',
#  'GO',
#  'BA',
#  'SP',
#  'CE',
#  'PE',
#  'BA',
#  'BA',
#  'CE',
#  'BA',
#  'RN',
#  'CE',
#  'BA',
#  'PE',
#  'AM',
#  'MT',
#  'SP',
#  'BA',
#  'CE',
#  'SP',
#  'CE',
#  'GO',
#  'GO',
#  'CE',
#  'PE',
#  'RN',
#  'PE',
#  'PE',
#  'DF',
#  'GO',
#  'CE',
#  'SP',
#  'CE',
#  'BA',
#  'BA',
#  'GO',
#  'PE',
#  'CE',
#  'SP',
#  'BA',
#  'BA',
#  'AL',
#  'BA',
#  'BA',
#  'SP',
#  'GO',
#  'GO',
#  'CE',
#  'MA',
#  'SP',
#  'GO',
#  'BA',
#  'RN',
#  'RN',
#  'SP',
#  'SP',
#  'CE',
#  'RN',
#  'RN',
#  'PE',
#  'GO',
#  'CE',
#  'RN',
#  'PA',
#  'MS',
#  'RN',
#  'SP',
#  'RN',
#  'BA',
#  'SP',
#  'PI',
#  'RN',
#  'CE',
#  'GO',
#  'CE',
#  'SP',
#  'BA',
#  'CE',
#  'SE',
#  'CE',
#  'PE',
#  'RN',
#  'PB',
#  'GO',
#  'BA',
#  'SP',
#  'BA',
#  'AM',
#  'SE',
#  'BA',
#  'BA',
#  'GO',
#  'PE',
#  'CE',
#  'SP',
#  'CE',
#  'CE',
#  'PE',
#  'RN',
#  'AL',
#  'SP',
#  'CE',
#  'PB',
#  'SE',
#  'CE',
#  'CE',
#  'SP',
#  'PE',
#  'BA',
#  'BA',
#  'CE',
#  'SP',
#  'GO',
#  'PE',
#  'BA',
#  'GO',
#  'PE',
#  'GO',
#  'CE',
#  'CE',
#  'CE',
#  'AM',
#  'RS',
#  'BA',
#  'DF',
#  'PE',
#  'PE',
#  'SP',
#  'CE',
#  'CE',
#  'DF',
#  'BA',
#  'AM',
#  'MT',
#  'BA',
#  'PE',
#  'BA',
#  'PE',
#  'RN',
#  'PE',
#  'BA',
#  'MA',
#  'CE',
#  'BA',
#  'BA',
#  'DF',
#  'PB',
#  'GO',
#  'CE',
#  'CE',
#  'CE',
#  'PE',
#  'CE',
#  'GO',
#  'CE',
#  'PE',
#  'BA',
#  'BA',
#  'CE',
#  'CE',
#  'BA',
#  'SP',
#  'PE',
#  'SP',
#  'SP',
#  'PB',
#  'BA',
#  'SP',
#  'MA',
#  'GO',
#  'SP',
#  'CE',
#  'BA',
#  'CE',
#  'RN',
#  'CE',
#  'BA',
#  'SP',
#  'PE',
#  'PE',
#  'CE',
#  'BA',
#  'SP',
#  'PB',
#  ...]

# %%
df['ESTADO'] = estado_lista

# %%
df.head()
# Out:
#           ID                                             TEMA           LOCAL  \
# 0  149490335                            TEMPO DE ATENDIMENTO      Recife - PE
# 1  149499817                       Hapvida não tem nutrólogo    Salvador - BA
# 2  149498293             Descaso de tratamento de Hemodiálise     Olinda - PE
# 3  149495455  DESORGANIZAÇÃO E FALTA DE RESOLUÇÃO DE PROBLEMA    Goiânia - GO
# 4  149495285                       Liberação de Procedimento   Fortaleza - CE
#
#        TEMPO                                          CATEGORIA  \
# 0 2022-01-09  Demora na execução<->Plano<->Planos de Saúde<-...
# 1 2022-01-09  Planos de saúde<->Qualidade do serviço prestad...
# 2 2022-01-09  Demora para autorização de consultas, exames e...
# 3 2022-01-09  Demora na execução<->Planos de saúde<->Planos ...
# 4 2022-01-09  Planos de saúde<->Planos de Saúde<->Hapvida Sa...
#
#            STATUS                                          DESCRICAO  \
# 0  Não respondida  Acabei de sair de uma urgência por causa de at...
# 1  Não respondida  O Hapvida diz que fornece o serviço de nutrólo...
# 2      Respondida  Meu irmão Wagner Santiago, estava internado de...
# 3  Não respondida  Agendei pelo chat um procedimento onde fui bem...
# 4      Respondida  Paguei fatura do plano em atraso e tal atraso ...
#
#                                                  URL   ANO  MES  DIA  \
# 0  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 1  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 2  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 3  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
# 4  https://www.reclameaqui.com.br//hapvida-saude/...  2022    1    9
#
#    DIA_DO_ANO  SEMANA_DO_ANO  DIA_DA_SEMANA  TRIMETRES  CASOS ESTADO
# 0           9              1              6          1     66     PE
# 1           9              1              6          1     66     BA
# 2           9              1              6          1     66     PE
# 3           9              1              6          1     66     GO
# 4           9              1              6          1     66     CE

# %%
df['ESTADO'].unique()
# Out:
# array(['PE', 'BA', 'GO', 'CE', 'SP', 'MA', 'PA', 'AL', 'RN', 'PB', '',
#        'MS', 'ES', 'AM', 'MT', 'SE', 'MG', 'RS', 'RR', 'RJ', 'SC', 'PI',
#        'TO', 'DF'], dtype=object)

# %%
df['ESTADO'].value_counts()
# Out:
# ESTADO
# CE    212
# PE    173
# BA    155
# SP    140
# GO     91
# RN     60
# PB     26
# AM     24
# PA     23
# MS     20
# AL     19
# MA     14
# SE     14
# MG      8
# DF      7
# MT      6
# SC      6
# PI      5
# RS      3
# ES      3
# RJ      3
#         2
# RR      1
# TO      1
# Name: count, dtype: int64

# %%
correcao_estados = {
    '': 'Não Consta'
}

# %%
df['ESTADO'] = df['ESTADO'].replace(correcao_estados)

# %%
df['ESTADO'].unique()
# Out:
# array(['PE', 'BA', 'GO', 'CE', 'SP', 'MA', 'PA', 'AL', 'RN', 'PB',
#        'Não Consta', 'MS', 'ES', 'AM', 'MT', 'SE', 'MG', 'RS', 'RR', 'RJ',
#        'SC', 'PI', 'TO', 'DF'], dtype=object)

# %%
df['ESTADO'].value_counts()
# Out:
# ESTADO
# CE            212
# PE            173
# BA            155
# SP            140
# GO             91
# RN             60
# PB             26
# AM             24
# PA             23
# MS             20
# AL             19
# MA             14
# SE             14
# MG              8
# DF              7
# MT              6
# SC              6
# PI              5
# RS              3
# ES              3
# RJ              3
# Não Consta      2
# RR              1
# TO              1
# Name: count, dtype: int64

# %%
def count_palavras(texto):
    return len(texto.split())

# %%
df['DESCRICAO'].apply(count_palavras).plot(kind='hist',density=True)
df['DESCRICAO'].apply(count_palavras).plot.kde()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 2
#       1 df['DESCRICAO'].apply(count_palavras).plot(kind='hist',density=True)
# ----> 2 df['DESCRICAO'].apply(count_palavras).plot.kde()
#
# File c:\Users\cissa\Desktop\streamlit_dashboard_py\streamlit_dashboard_py\venv\Lib\site-packages\pandas\plotting\_core.py:1522, in PlotAccessor.kde(self, bw_method, ind, **kwargs)
#    1411 def kde(
#    1412     self,
#    1413     bw_method: Literal["scott", "silverman"] | float | Callable | None = None,
#    1414     ind: np.ndarray | int | None = None,
#    1415     **kwargs,
#    1416 ) -> PlotAccessor:
#    1417     """
#    1418     Generate Kernel Density Estimate plot using Gaussian kernels.
#    1419
#    (...)   1520         >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1521     """
# -> 1522     return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#
# File c:\Users\cissa\Desktop\streamlit_dashboard_py\streamlit_dashboard_py\venv\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\cissa\Desktop\streamlit_dashboard_py\streamlit_dashboard_py\venv\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File c:\Users\cissa\Desktop\streamlit_dashboard_py\streamlit_dashboard_py\venv\Lib\site-packages\pandas\plotting\_matplotlib\core.py:501, in MPLPlot.generate(self)
#     499 self._compute_plot_data()
#     500 fig = self.fig
# --> 501 self._make_plot(fig)
#     502 self._add_table()
#     503 self._make_legend()
#
# File c:\Users\cissa\Desktop\streamlit_dashboard_py\streamlit_dashboard_py\venv\Lib\site-packages\pandas\plotting\_matplotlib\hist.py:168, in HistPlot._make_plot(self, fig)
#     164     kwds["weights"] = type(self)._get_column_weights(self.weights, i, y)
#     166 y = reformat_hist_y_given_by(y, self.by)
# --> 168 artists = self._plot(ax, y, column_num=i, stacking_id=stacking_id, **kwds)
#     170 # when by is applied, show title for subplots to know which group it is
#     171 if self.by is not None:
#
# File c:\Users\cissa\Desktop\streamlit_dashboard_py\streamlit_dashboard_py\venv\Lib\site-packages\pandas\plotting\_matplotlib\hist.py:276, in KdePlot._plot(cls, ax, y, style, bw_method, ind, column_num, stacking_id, **kwds)
#     263 @classmethod
#     264 # error: Signature of "_plot" incompatible with supertype "MPLPlot"
#     265 def _plot(  #  type: ignore[override]
#    (...)    274     **kwds,
#     275 ):
# --> 276     from scipy.stats import gaussian_kde
#     278     y = remove_na_arraylike(y)
#     279     gkde = gaussian_kde(y, bw_method=bw_method)
#
# ModuleNotFoundError: No module named 'scipy'
